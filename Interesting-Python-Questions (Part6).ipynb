# %% [markdown]
# ### Question - 101

# %%
'bcd' or 'a'
# Out:
# 'bcd'

# %%
77 or ''
# Out:
# 77

# %%
'a' or 'bcd'
# Out:
# 'a'

# %%
'' or 77
# Out:
# 77

# %% [markdown]
# ##### Note:- The function returns the truth value of some condition.
# Predicate

# %% [markdown]
# ### Question - 102

# %%
x = []

def af(b):
    x.append(b)
    return(x)
    
def ab(f):
    f += '1'
    return f

len(af(ab([1,0])))
# Out:
# 1

# %%
x = []

def af(b):
    x.append(b)
    return(x)
    
def ab(f):
    f += '1'
    return f


ab([1,0])
# Out:
# [1, 0, '1']

# %%
x = []

    
def ab(f):
    f += '1'
    return f

ab([1,0])
# Out:
# [1, 0, '1']

# %%
def abc(f):
    f += '1'
    return f

abc([1,0])
# Out:
# [1, 0, '1']

# %% [markdown]
# ### Question - 103

# %%
def rec(x,y):
    if x == 0:
        return y
    if x != 0:
        return rec(x-1, y+1)

rec(3,4)
# Out:
# 7

# %%
rec(0,100)
# Out:
# 100

# %%
#untill x becomes zero, add 1 to y. ideally we will get x+y

# %% [markdown]
# ### Question - 104

# %%
def generator(n):
    i = n
    while i >= 0:
        if i%3 == 0:
            yield i*i
        i -= 1

for k in generator(6):
    print(k, sep='', end='')
# Out:
# 3690

# %%
#note:
6*6, 3*3, 0*0
# Out:
# (36, 9, 0)

# %% [markdown]
# ### Question - 105

# %%
l = [1,2,3,4,5]

l[:1:-1]
#remember l[::-1]
# Out:
# [5, 4, 3]

# %%
l[-1:1:-1]
# Out:
# [5, 4, 3]

# %%
l[0:1:-1]
# Out:
# []

# %% [markdown]
# ### Question - 106

# %%
a = [1,2,3]
a[:3:0][1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-b641a51a1d81> in <module>
#       1 a = [1,2,3]
# ----> 2 a[:3:0][1]
#
# ValueError: slice step cannot be zero

# %%
# answer is valueerror

# %% [markdown]
# ### Question - 107

# %%
a = {1,2,3}
a.add(0)
len(a)
# Out:
# 4

# %% [markdown]
# ### Question - 108

# %%
x = {'a':1, 'b':2, 'c':3}
import random
random.choice(x)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-be354e603beb> in <module>
#       1 x = {'a':1, 'b':2, 'c':3}
#       2 import random
# ----> 3 random.choice(x)
#
# ~\AppData\Local\Continuum\anaconda3\lib\random.py in choice(self, seq)
#     260         except ValueError:
#     261             raise IndexError('Cannot choose from an empty sequence') from None
# --> 262         return seq[i]
#     263
#     264     def shuffle(self, x, random=None):
#
# KeyError: 2

# %%
# answer is key error

# %%
y = {1:'a', 2:'b', 3:'c'}
import random
random.choice(y)
# Out:
# 'b'

# %% [markdown]
# ### Question - 109

# %%
for i in range(9):
    if i == True:
        print(i+1)
        break
# Out:
# 2

# %% [markdown]
# ### Question - 110

# %%
def fun(*s):
    print(s)

fun('abcd')
# Out:
# ('abcd',)

# %%
fun('a', 'b')
# Out:
# ('a', 'b')

# %%
fun(1,2,3)
# Out:
# (1, 2, 3)

# %% [markdown]
# ### Question - 111

# %%
t = [2,3,4]

for i in t:
    if i%2:
        t.append(i)
print(t)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-107-e75dc75f3e45> in <module>
#       3 for i in t:
#       4     if i%2:
# ----> 5         t.append(i)
#       6 print(t)
#
# KeyboardInterrupt:

# %%
# answer is infinite loop

# %%
# Note:

type((1,)), type((1))
# Out:
# (tuple, int)

# %% [markdown]
# ### Question - 112

# %%
s={}

# %%
t = {1}

# %%
type(s) == type(t)
# Out:
# False

# %%
x = 'ab'

# %%
x[0] = 'h'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-749a68d98a9c> in <module>
# ----> 1 x[0] = 'h'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ### Question - 112

# %%
def myAdd(x=2, y=4, *args):
    while (x<y):
        for ar in range(len(args)):
            return (x+y+args[ar+2])
            break
print(myAdd(3,4,5,6,9))
# Out:
# 16

# %%
def myAdd(x=2, y=4, *args):
    while (x<y):
        for ar in range(len(args)):
            print (x,y,args[ar+2])
            break
myAdd(3,4,5,6,9)
# Out:
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# 3 4 9
# ...

# %%
a = [1,2,3,4]

# %%
for i in range(len(out[0]['port-list'])):
    print(out[0]['port-list'][i]['stats']['total_req'])
# Out:
# 1762805
# 23

# %%
for i in range(len(out)):
    x=0
    for j in range(len(out[i]['port-list'])):
        x += out[i]['port-list'][j]['stats']['total_req']
    dict1['hits'].append(x)

# %%
dict1
# Out:
# {'rule': ['api_news', 'vip2', 'vip2_v6'],
#  'hits': [1762828, 141346851, 596128800]}

# %%
1762805+23, 140550684+796167, 595455220+673580
# Out:
# (1762828, 141346851, 596128800)

# %% [markdown]
# ### Question - 113

# %%
round(43934.789,-2)
# Out:
# 43900.0

# %% [markdown]
# ### Question - 114

# %%
a = [3,4,2]
b = sorted(a)
b.insert(0,1)
a[0]
# Out:
# 3

# %%
b[0]
# Out:
# 1

# %% [markdown]
# ### Question - 115

# %%
binary = '1010'
flip = ''
for i in binary:
    if i == '0':
        flip += '1'
    else:
        flip += '0'
print(flip)
# Out:
# 0101

# %% [markdown]
# ### Question - 116

# %%
def ishash(x):
    try:
        set = {x}
        return True
    except TypeError:
        return False

print(ishash(2), ishash([2]))
# Out:
# True False

# %%
a, b =  2, [2]

# %%
{a}
# Out:
# {2}

# %%
{b}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-92-e24f01ff7ae9> in <module>
# ----> 1 {b}
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# ### Question - 117

# %%
tup = {}
tup[(1,2,4)] = 8
tup[(4,2,1)] = 10
tup[(1,2)] = 12
_sum = 0

for k in tup:
    _sum += tup[k]

print(len(tup) + _sum)
# Out:
# 33

# %%
tup
# Out:
# {(1, 2, 4): 8, (4, 2, 1): 10, (1, 2): 12}

# %%
for i in tup:
    print(tup[i])
# Out:
# 8
# 10
# 12

# %%
len(tup)
# Out:
# 3

# %% [markdown]
# ### Question - 118

# %%
d = {True:'sun'}
d[1] = 'moon'
d[True]
# Out:
# 'moon'

# %% [markdown]
# ### Question - 119

# %%
a_list = [3,-4,-2,5,1]
print(sorted(a_list, key=lambda x:abs(x)))
# Out:
# [1, -2, 3, -4, 5]

# %% [markdown]
# ### Question - 120

# %%
a = [5,3,8,2,1]
b = sorted(a)
print(a)
# Out:
# [5, 3, 8, 2, 1]

# %%
b
# Out:
# [1, 2, 3, 5, 8]

# %%
#Note:(different context - reverse)-

reversed(a), list(reversed(a))
# Out:
# (<list_reverseiterator at 0x7f5ada3c2cc0>, [1, 2, 8, 3, 5])

# %% [markdown]
# ### Question - 121

# %%
A = [1,2,3,4,1]
for n in A:
    A[n] = 0
print(A)
# Out:
# [0, 0, 3, 0, 1]

# %%
A = [1,2,3,4,1]
for n in A:
    print(n, A[n])
    A[n] = 0
    print(A)
# Out:
# 1 2
# [1, 0, 3, 4, 1]
# 0 1
# [0, 0, 3, 4, 1]
# 3 4
# [0, 0, 3, 0, 1]
# 0 0
# [0, 0, 3, 0, 1]
# 1 0
# [0, 0, 3, 0, 1]

# %% [markdown]
# ### Question - 122

# %%
#fill in blanks to get output [11,33,55]

nums = [11,22,33,44,55]
res = list(filter(lambda x:not(x%2==0), nums))
res

# position od not is blank in question
# Out:
# [11, 33, 55]

# %% [markdown]
# ### Question - 123

# %%
A = [[]]*3
A[0].append(3)
A
# Out:
# [[3], [3], [3]]

# %%
#note
a = [[], [], []]
a[0].append(3)
a
# Out:
# [[3], [], []]

# %% [markdown]
# ### Question - 124

# %%
x = 2
y = 42
i = 0
z = (y//x)%x

while i <= x:
    z = z+i
    i += 1
print(z)
# Out:
# 4

# %%
x = 2
y = 42
i = 0
z = (y//x)%x

z
# Out:
# 1

# %%
while i <= x:
    z = z+i
    print(f'z is {z}')
    i += 1
    print(f'i is {i}')
print(z)
# Out:
# z is 1
# i is 1
# z is 2
# i is 2
# z is 4
# i is 3
# 4

# %% [markdown]
# ### Question - 125

# %%
n, i, cont = 10, 10, 0

while n//i == 1:
    i = i-1
    cont = cont+1

cont
# Out:
# 5

# %%
n, i, cont = 10, 10, 0

while n//i == 1:
    print(f'n is {n} and i is {i}')
    i = i-1
    print(f'i is {i} after doing i=i-1')
    cont = cont+1
    print(f'cont is {cont}')
# Out:
# n is 10 and i is 10
# i is 9 after doing i=i-1
# cont is 1
# n is 10 and i is 9
# i is 8 after doing i=i-1
# cont is 2
# n is 10 and i is 8
# i is 7 after doing i=i-1
# cont is 3
# n is 10 and i is 7
# i is 6 after doing i=i-1
# cont is 4
# n is 10 and i is 6
# i is 5 after doing i=i-1
# cont is 5

# %% [markdown]
# ### Question - 126

# %%
def f(q, mylist=[]):
    mylist = mylist + q
    return mylist

a = [1]
print(f(a))
a = [2]
print(f(a))
# Out:
# [1]
# [2]

# %% [markdown]
# ### Question - 127

# %%
a = [(1,0), [1,2,3], {1:'a', 4:'b'}]
lst = []

for n in a:
    lst.extend(n)
len(lst)
# Out:
# 7

# %%
lst
# Out:
# [1, 0, 1, 2, 3, 1, 4]

# %%
a = [(1,0), [1,2,3], {1:'a', 4:'b'}]
for i in a:
    print(i)
# Out:
# (1, 0)
# [1, 2, 3]
# {1: 'a', 4: 'b'}

# %%
#extend function append members inside iterables.

# %% [markdown]
# ### Question - 128

# %%
print(type((1,2)).__name__)
# Out:
# tuple
