# %%
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get('https://en.wikipedia.org/wiki/Programming_languages_used_in_most_popular_websites')
print(response)
# Out:
# <Response [200]>

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Programming languages used in most popular websites - Wikipedia</title>
# ...

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Programming languages used in most popular websites - Wikipedia</title>
# ...

# %%
print(soup.body)
# Out:
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-Programming_languages_used_in_most_popular_websites rootpage-Programming_languages_used_in_most_popular_websites skin-vector action-view skin-vector-legacy"><div class="noprint" id="mw-page-base"></div>
# <div class="noprint" id="mw-head-base"></div>
# <div class="mw-body" id="content" role="main">
# <a id="top"></a>
# <div id="siteNotice"><!-- CentralNotice --></div>
# <div class="mw-indicators">
# </div>
# <h1 class="firstHeading" id="firstHeading">Programming languages used in most popular websites</h1>
# <div class="vector-body" id="bodyContent">
# <div class="noprint" id="siteSub">From Wikipedia, the free encyclopedia</div>
# <div id="contentSub"></div>
# <div id="contentSub2"></div>
# <div id="jump-to-nav"></div>
# <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>
# <a class="mw-jump-link" href="#searchInput">Jump to search</a>
# ...

# %%
print(soup.title)
# Out:
# <title>Programming languages used in most popular websites - Wikipedia</title>

# %%
soup.find_all('div')
# Out:
# [<div class="noprint" id="mw-page-base"></div>,
#  <div class="noprint" id="mw-head-base"></div>,
#  <div class="mw-body" id="content" role="main">
#  <a id="top"></a>
#  <div id="siteNotice"><!-- CentralNotice --></div>
#  <div class="mw-indicators">
#  </div>
#  <h1 class="firstHeading" id="firstHeading">Programming languages used in most popular websites</h1>
#  <div class="vector-body" id="bodyContent">
#  <div class="noprint" id="siteSub">From Wikipedia, the free encyclopedia</div>
#  <div id="contentSub"></div>
#  <div id="contentSub2"></div>
#  <div id="jump-to-nav"></div>
#  <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>
#  <a class="mw-jump-link" href="#searchInput">Jump to search</a>
#  <div class="mw-body-content mw-content-ltr" dir="ltr" id="mw-content-text" lang="en"><div class="mw-parser-output"><p>
# ...

# %%
soup.find('p') # first item with <p>
# Out:
# <p>
# One thing the most visited <a href="/wiki/Website" title="Website">websites</a> have in common that they are <a href="/wiki/Website#Dynamic_website" title="Website">dynamic websites</a>. Their <a href="/wiki/Web_development" title="Web development">development</a> typically involves <a href="/wiki/Web_development#Server_side_coding" title="Web development">server-side coding</a>, <a href="/wiki/Web_development#Client_side_coding" title="Web development">client-side coding</a> and <a href="/wiki/Web_development#Database_technology" title="Web development">database technology</a>. The programming languages applied to deliver similar dynamic web content however vary vastly between sites.
# </p>

# %%
import pandas as pd
df = pd.read_html('https://en.wikipedia.org/wiki/Programming_languages_used_in_most_popular_websites')

# %%
df
# Out:
# [         Websites  Popularity(unique visitors per month)[1]  \
#  0       Google[2]                                1600000000
#  1        Facebook                                1120000000
#  2         YouTube                                1100000000
#  3           Yahoo                                 750000000
#  4          Amazon                                 500000000
#  5       Wikipedia                                 475000000
#  6         Twitter                                 290000000
#  7            Bing                                 285000000
#  8            eBay                                 285000000
#  9             MSN                                 280000000
#  10       LinkedIn                                 260000000
#  11      Pinterest                                 250000000
#  12  WordPress.com                                 240000000
#
#      Front-end(Client-side)                              Back-end(Server-side)  \
# ...

# %%
type(df)
# Out:
# list

# %%
df[0]
# Out:
#          Websites  Popularity(unique visitors per month)[1]  \
# 0       Google[2]                                1600000000
# 1        Facebook                                1120000000
# 2         YouTube                                1100000000
# 3           Yahoo                                 750000000
# 4          Amazon                                 500000000
# 5       Wikipedia                                 475000000
# 6         Twitter                                 290000000
# 7            Bing                                 285000000
# 8            eBay                                 285000000
# 9             MSN                                 280000000
# 10       LinkedIn                                 260000000
# 11      Pinterest                                 250000000
# 12  WordPress.com                                 240000000
#
#     Front-end(Client-side)                              Back-end(Server-side)  \
# ...
