# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ts = pd.date_range('01-01-2020', periods=30, freq='d')

# %%
df = pd.DataFrame({'sales':np.random.randint(50,200,30)}, index=ts)

# %%
df.plot()

# %%
ser1 = pd.Series(np.random.randint(10,50,30), index=ts)

# %%
ser1
# Out:
# 2020-01-01    24
# 2020-01-02    14
# 2020-01-03    11
# 2020-01-04    46
# 2020-01-05    22
# 2020-01-06    11
# 2020-01-07    28
# 2020-01-08    36
# 2020-01-09    26
# 2020-01-10    31
# 2020-01-11    38
# 2020-01-12    37
# 2020-01-13    12
# 2020-01-14    31
# 2020-01-15    26
# 2020-01-16    43
# 2020-01-17    28
# 2020-01-18    44
# 2020-01-19    41
# 2020-01-20    29
# 2020-01-21    25
# 2020-01-22    47
# 2020-01-23    14
# 2020-01-24    38
# 2020-01-25    42
# 2020-01-26    21
# 2020-01-27    48
# 2020-01-28    15
# 2020-01-29    22
# 2020-01-30    45
# Freq: D, dtype: int32

# %%
ser1.plot()

# %%
ser2 = pd.Series(np.arange(30), index=ts)

# %%
ser2.plot()

# %%
# note: same thing we can plot with plt.plot in matplotlib.pyplot

plt.plot(ser2)

# %%
df.plot(figsize=(15, 5))  # a tuple (width, height) in inches

# %%
df.plot(figsize=(15,5), title='Day wise sales')

# %%
df.plot(figsize=(15,5), title='Day wise sales', legend=True)

# %%
df2 = pd.read_clipboard()

# %%
df2
# Out:
#     Age  Salary
# 0    23    2329
# 1    24    4264
# 2    25    7588
# 3    25    9316
# 4    26   11124
# 5    28   15204
# 6    28   15248
# 7    29   17552
# 8    29   19274
# 9    30   20051
# 10   31   21320
# 11   33   22491
# 12   34   30510
# 13   34   31437
# 14   34   33378
# 15   35   33515
# 16   36   34541
# 17   36   34763
# 18   37   36899
# 19   37   38744
# 20   39   39648

# %%
df2.plot(x='Age', y='Salary')

# %%
df3 = pd.read_clipboard()

# %%
df3
# Out:
#     Age  Salary  experience
# 0    20   10741           1
# 1    22   10910           2
# 2    22   11414           2
# 3    22   11728           2
# 4    23   12260           3
# 5    26   13041           3
# 6    26   13285           4
# 7    30   14745           5
# 8    32   16727           6
# 9    35   17652           6
# 10   37   17963           7
# 11   38   19283           8
# 12   39   20452          10
# 13   41   20535          10
# 14   42   20842          10
# 15   43   21393          10
# 16   44   22301          11
# 17   47   24757          12
# 18   50   24995          12

# %%
df3.plot(x='Age', y='Salary')

# %%
ax = df.plot(figsize=(15,5), title='Day wise sales')
ax.set_xlabel('Date')
ax.set_ylabel('Sale count')
# Out:
# Text(0, 0.5, 'Sale count')

# %%
df.plot(figsize=(15,5), title='Day wise sales', kind='bar')

# %%
df.plot(figsize=(5,15), title='Day wise sales', kind='barh')

# %%
df3.plot(x='Age', y='Salary', kind='scatter')

# %%
df.plot(figsize=(15,5), title='Day wise sales', kind='box')

# %%
df3.plot(x='experience', y='Salary', kind='box')

# %%
df.plot(figsize=(15,5), title='Histogram', kind='hist')

# %%
df.plot(figsize=(15,5), title='Histogram', kind='kde')

# %%
df.plot(figsize=(15,5), title='day wise sales', kind='area')

# %%
df3.plot(x='Age', y='Salary', kind='hexbin')

# %%
df4 = pd.DataFrame({'Name':['a', 'b', 'c'], 'cont':[50,30,20]})

# %%
df4.set_index('Name', inplace=True)

# %%
df4.plot(kind='pie', y='cont')

# %%
df.plot(c='r', marker='o')

# %%
df.plot(c='r', marker='o', markersize=10)

# %%
df = pd.read_csv(r'E:\sample_data\students.csv')

# %%
df.head()
# Out:
#   student name  student id  maths mark  english mark
# 0    student-1           1          20             9
# 1    student-2           2           7            31
# 2    student-3           3          20            82
# 3    student-4           4          78            98
# 4    student-5           5          73             7

# %%
df.plot(kind='scatter', x = 'student id', y='english mark', c='english mark')

# %%
d = df.iloc[:5,:]

# %%
d.set_index('student name', inplace=True)

# %%
d
# Out:
#               student id  maths mark  english mark
# student name
# student-1              1          20             9
# student-2              2           7            31
# student-3              3          20            82
# student-4              4          78            98
# student-5              5          73             7

# %%
d.plot(kind='pie', subplots=True, figsize=(15,15), autopct='%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000230A09DCE50>,
# ...
#       dtype=object)

# %%
d2 = pd.DataFrame({'a':[5,6,7,8,9], 'b':[3,5,6,8,10]})

# %%
d2
# Out:
#    a   b
# 0  5   3
# 1  6   5
# 2  7   6
# 3  8   8
# 4  9  10

# %%
d3 = pd.DataFrame({'a':[1,2,3,2,4], 'b':[2,1,6,8,10]})

# %%
d3
# Out:
#    a   b
# 0  1   2
# 1  2   1
# 2  3   6
# 3  2   8
# 4  4  10

# %%
d2.plot()
d3.plot(secondary_y=True)

# %%
ax = d2.plot()
d3.plot(secondary_y=True, ax=ax)
